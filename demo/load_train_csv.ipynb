# %%
import pandas as pd

# %%
df = pd.read_csv("d:\\works\\AVA\\frame_lists\\train.csv", delim_whitespace=True,dtype={"labels":str})

# %%
df
# Out:
#         original_vido_id  video_id  frame_id  \
# 0            -5KQ66BBWC4         0         0
# 1            -5KQ66BBWC4         0         1
# 2            -5KQ66BBWC4         0         2
# 3            -5KQ66BBWC4         0         3
# 4            -5KQ66BBWC4         0         4
# ...                  ...       ...       ...
# 6352099      zlVkeKC6Ha8       234     27025
# 6352100      zlVkeKC6Ha8       234     27026
# 6352101      zlVkeKC6Ha8       234     27027
# 6352102      zlVkeKC6Ha8       234     27028
# 6352103      zlVkeKC6Ha8       234     27029
#
#                                        path labels
# 0        -5KQ66BBWC4/-5KQ66BBWC4_000001.jpg    NaN
# 1        -5KQ66BBWC4/-5KQ66BBWC4_000002.jpg    NaN
# 2        -5KQ66BBWC4/-5KQ66BBWC4_000003.jpg    NaN
# 3        -5KQ66BBWC4/-5KQ66BBWC4_000004.jpg    NaN
# 4        -5KQ66BBWC4/-5KQ66BBWC4_000005.jpg    NaN
# ...                                     ...    ...
# 6352099  zlVkeKC6Ha8/zlVkeKC6Ha8_027026.jpg    NaN
# ...

# %%
train_vids = set(df["original_vido_id"])

# %%
len(train_vids)
# Out:
# 235

# %%
for vid in train_vids:
    print(vid.replace(",",""))
# Out:
# zG7mx8KiavA
# uzPI7FcF79U
# PcFEhUKhN6g
# 0wBYFahr3uI
# uq_HBsvP548
# P60OxWahxBQ
# Riu4ZKk4YdQ
# 9HOMUW7QNFc
# 3_VjIRdXVdM
# O5m_0Yay4EU
# XF87VL5T0aA
# yvgCGJ6vfkY
# U_WzY2k8IBM
# qsTqtWVVSLM
# cWYJHb25EVs
# 2KpThOF_QmE
# 2bxKkUgcqpk
# 0f39OWEqJ24
# 9eAOr_ttXp0
# IuPC-z-M9u8
# jqZpiHlJUig
# 2fwni_Kjf2M
# S0tkhGJjwLA
# qBUu7cy-5Iw
# wogRuPNBUi8
# QJzocCGLdHU
# sADELCyj10I
# phVLLTMzmKk
# Feu1_8NazPE
# X5wWhZ2r9kc
# _-Z6wFjXtGQ
# XglAvHaEtHY
# qrkff49p4E4
# _ithRWANKB0
# fD6VkIRlIRI
# T26G6_AjJZ4
# oWhvucAskhk
# 9IF8uTRrWAM
# QMwT7DFA5O4
# N5UD8FGzDek
# kplbKz3_fZk
# _Ca3gOdOHxU
# UgZFdrNT6W0
# miB-wo2PfLI
# v0L-WkMO3s4
# G5Yr20A5z_Q
# j35JnR0Q7Es
# 2FIHxnZKg6A
# sUVhd0YTKgw
# KIy2a-nejxg
# bAVXp1oGjHA
# 1ReZIMmD_8E
# GBXK_SyfisM
# fZs-yXm-uUs
# oITFHwzfw_k
# BY3sZmvUp-0
# yo-Kg2YxlZs
# b50s4AlOOKY
# eA55_shhKko
# Ag-pXiLrd48
# kMy-6RtoOVU
# bSZiZ4rOC7c
# y7ncweROe9U
# plkJ45_-pMk
# QaIMUi-elFo
# N7baJsMszJ0
# C3qk4yAMANk
# _145Aa_xkuE
# QotkBTEePI8
# 2E_e8JlvTlg
# fNcxxBjEOgw
# ...

# %%
val_df = pd.read_csv("d:\\works\\AVA\\frame_lists\\val.csv", delim_whitespace=True,dtype={"labels":str})

# %%
val_vids = set(val_df["original_vido_id"])

# %%
len(val_vids)
# Out:
# 64

# %%
for vid in val_vids:
    print(vid.replace(",",""))
# Out:
# 2PpxiG0WU18
# QCLQYnt3aMo
# G4qq1MRXCiY
# rXFlJbXyZyc
# O_NYCUhZ9zw
# BXCh3r-pPAM
# Ov0za6Xb1LM
# NO2esmws190
# z-fsLpGHq6o
# KVq6If6ozMY
# ZosVdkY76FU
# covMYDBa5dk
# fpprSy6AzKk
# Hscyg0vLKc8
# jE0S8gYWftE
# yn9WN9lsHRE
# 1j20qq1JyX4
# 9F2voT6QWvQ
# o4xQ-BEa3Ss
# oifTDWZvOhY
# b-YoBU0XT90
# TEQ9sAj-DPo
# ayAMdYfJJLk
# u1ltv6r14KQ
# Gvp-cj3bmIY
# CZ2NP8UsPuE
# IzvOYVMltkI
# UOyyTUX5Vo4
# tghXjom3120
# XpGRS72ghag
# 914yZXz-iRs
# lDmLcWWBp1E
# 7T5G0CmwTPo
# OGNnUvJq9RI
# j5jmjhGBW44
# xeGWXqSvC-8
# om_83F5VwTQ
# _7oWZq_s_Sk
# qx2vAO5ofmo
# 9Y_l9NsnYE0
# 55Ihr6uVIDA
# uNT6HrrnqPU
# QTmwhrVal1g
# _eBah6c5kyA
# bePts02nIY8
# nlinqZPgvVk
# SCh-ZImnyyk
# Ekwy7wzLfjc
# UrsCy6qIGoo
# l2XO3tQk8lI
# KHHgQ_Pe4cI
# sNQJfYvhcPk
# wONG7Vh87B4
# Lg1jOu8cUBM
# _dBTTYDRdRQ
# zC5Fh2tTS1U
# 6d5u6FHvz7Q
# hHgg9WI8dTk
# CMCPhm2L400
# 5BDj0ow5hnA
# Di1MG6auDYo
# Z1YV6wB037M
# WSPvfxtqisg
# er7eeiJB6dI

# %%
vids = train_vids | val_vids

# %%
len(vids)
# Out:
# 299
